# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

# %%
x = np.arange(1, 1001, 1)
x = x.reshape(-1, 1)
x[::100]
# Out:
# array([[  1],
#        [101],
#        [201],
#        [301],
#        [401],
#        [501],
#        [601],
#        [701],
#        [801],
#        [901]])

# %%
np.random.seed(42)

slope = np.random.randint(15)
print(slope)
intercept = np.random.randint(100)
print(intercept)
# Out:
# 6
# 51

# %%
y = x * (slope + np.random.rand(len(x), 1)) + intercept + np.random.rand(len(x), 1) * 1000
y[:10]
# Out:
# array([[853.92837599],
#        [315.28040795],
#        [694.62273821],
#        [647.83378205],
#        [917.6273681 ],
#        [995.78549954],
#        [110.59374538],
#        [773.54284832],
#        [161.22393986],
#        [660.19480108]])

# %%
y.shape
# Out:
# (1000, 1)

# %%
plt.scatter(x, y, c="b")

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x = sc.fit_transform(x)

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd = SGDRegressor(loss="squared_error", max_iter=1000, random_state=42)

# %%
sgd.fit(x, y.reshape(len(x), ))
# Out:
# SGDRegressor(random_state=42)

# %%
sgd.coef_
# Out:
# array([1882.12770545])

# %%
sgd.intercept_
# Out:
# array([3795.64695672])

# %%
y_sgd = x * sgd.coef_[0] + sgd.intercept_[0]
y_sgd[:5]
# Out:
# array([[538.96445702],
#        [545.48434191],
#        [552.00422679],
#        [558.52411167],
#        [565.04399656]])

# %%
plt.scatter(x, y, c="b")
plt.plot(x, y_sgd, c="r")
